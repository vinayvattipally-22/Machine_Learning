# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
# Out:
# WARNING:tensorflow:From c:\Users\vinay\anaconda3\envs\dev\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Import our input dataset
myopia_df = pd.read_csv('https://static.bc-edx.com/data/dl-1-2/m21/lessons/2/myopia.csv')
myopia_df.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# 0        0    10         34      1      1       1
# 1        1     7         12      1      1       0
# 2        0    10         14      0      0       0
# 3        0     4         37      0      1       1
# 4        0     4          4      1      0       0

# %%
# Remove MYOPIC target from features data
y = myopia_df.MYOPIC.values
X = myopia_df.drop(columns=['MYOPIC']).values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Preprocess numerical data for neural network
numerical_features = myopia_df.dtypes[myopia_df.dtypes != 'int64'].index.tolist()
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler on training data
scaler.fit(X_train)

# Transform the training and test data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Define the deep learning model
 
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  8
hidden_nodes_layer2 = 5

# Compile the Sequential model together and customize metrics
model = tf.keras.models.Sequential()

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test, verbose=2)
# Out:
# WARNING:tensorflow:From c:\Users\vinay\anaconda3\envs\dev\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\vinay\anaconda3\envs\dev\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\vinay\anaconda3\envs\dev\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 15/15 [==============================] - 2s 12ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 2/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 3/100
# 15/15 [==============================] - 0s 5ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 4/100
# 15/15 [==============================] - 0s 5ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 5/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 6/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 7/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 8/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 9/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 10/100
# 15/15 [==============================] - 0s 12ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 11/100
# 15/15 [==============================] - 0s 8ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 12/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 13/100
# 15/15 [==============================] - 0s 5ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 14/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 15/100
# 15/15 [==============================] - 0s 8ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 16/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 17/100
# 15/15 [==============================] - 0s 8ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 18/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 19/100
# 15/15 [==============================] - 0s 8ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 20/100
# 15/15 [==============================] - 0s 11ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 21/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 22/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 23/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 24/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 25/100
# 15/15 [==============================] - 0s 8ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 26/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 27/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 28/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 29/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 30/100
# 15/15 [==============================] - 0s 8ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 31/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 32/100
# 15/15 [==============================] - 0s 5ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 33/100
# 15/15 [==============================] - 0s 8ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 34/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 35/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 36/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 37/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 38/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 39/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 40/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 41/100
# 15/15 [==============================] - 0s 8ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 42/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 43/100
# 15/15 [==============================] - 0s 8ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 44/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 45/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 46/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 47/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 48/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 49/100
# 15/15 [==============================] - 0s 10ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 50/100
# 15/15 [==============================] - 0s 11ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 51/100
# 15/15 [==============================] - 0s 17ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 52/100
# 15/15 [==============================] - 0s 10ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 53/100
# 15/15 [==============================] - 0s 16ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 54/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 55/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 56/100
# 15/15 [==============================] - 0s 10ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 57/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 58/100
# 15/15 [==============================] - 0s 14ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 59/100
# 15/15 [==============================] - 0s 14ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 60/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 61/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 62/100
# 15/15 [==============================] - 0s 8ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 63/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 64/100
# 15/15 [==============================] - 0s 11ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 65/100
# 15/15 [==============================] - 0s 10ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 66/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 67/100
# 15/15 [==============================] - 0s 11ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 68/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 69/100
# 15/15 [==============================] - 0s 8ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 70/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 71/100
# 15/15 [==============================] - 0s 12ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 72/100
# 15/15 [==============================] - 0s 12ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 73/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 74/100
# 15/15 [==============================] - 0s 14ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 75/100
# 15/15 [==============================] - 0s 14ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 76/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 77/100
# 15/15 [==============================] - 0s 6ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 78/100
# 15/15 [==============================] - 0s 12ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 79/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 80/100
# 15/15 [==============================] - 0s 8ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 81/100
# 15/15 [==============================] - 0s 12ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 82/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 83/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 84/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 85/100
# 15/15 [==============================] - 0s 12ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 86/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 87/100
# 15/15 [==============================] - 0s 14ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 88/100
# 15/15 [==============================] - 0s 12ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 89/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 90/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 91/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 92/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 93/100
# 15/15 [==============================] - 0s 11ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 94/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 95/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 96/100
# 15/15 [==============================] - 0s 9ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 97/100
# 15/15 [==============================] - 0s 11ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 98/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 99/100
# 15/15 [==============================] - 0s 14ms/step - loss: 3.4069 - accuracy: 0.0842
# Epoch 100/100
# 15/15 [==============================] - 0s 10ms/step - loss: 3.4069 - accuracy: 0.0842
# 5/5 - 2s - loss: 3.2176 - accuracy: 0.1032 - 2s/epoch - 319ms/step
